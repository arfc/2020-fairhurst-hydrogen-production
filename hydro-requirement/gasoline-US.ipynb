# %%
Barrels per year from 1986 to 2012
https://www.indexmundi.com/energy/?country=us&product=gasoline&graph=consumption

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv("gasoline-year.csv")
plt.plot(df1['year'], df1['consumption(barrels)'])
plt.title('Barrels per year')
plt.ylabel('Barrels')
plt.xlabel('year')
# Out:
# Text(0.5, 0, 'year')

# %%
A barrel are 42 gallons of crude oil, that make 19 gallons of gasoline.
http://www.todayifoundout.com/index.php/2014/04/large-barrel-oil-measure-way/
